# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = 'https://www.dawn.com/'

response = requests.get(url)

response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text, 'html.parser')
#print(soup.prettify())

# %%
for article in articles:
    headline_tag = article.find('h2')   # gets the h2 inside the article
    link_tag = article.find('a')        # gets the a inside the article
# Out:
# -1

# %%
base_url = "https://www.dawn.com"
data = []

h2_tags = soup.find_all('h2')

for h2 in h2_tags:
    headline = h2.text.strip()
    link = h2.a['href'] if h2.a and h2.a.has_attr('href') else None
    if link:
        if link.startswith('/'):
            link = base_url + link
        data.append({"Headline": headline, "Link": link})

data
# Out:
# [{'Headline': 'E-Paper | March 27, 2025', 'Link': 'https://epaper.dawn.com'},
#  {'Headline': 'End of live blog for elections 2024',
#   'Link': 'https://www.dawn.com/live/elections-2024#1822566'},
#  {'Headline': 'Scrutiny concludes for nomination papers of 48 Senate seats',
#   'Link': 'https://www.dawn.com/live/elections-2024#1822564'},
#  {'Headline': 'ECP notifies Mahmood Khan as PTI-P chairman',
#   'Link': 'https://www.dawn.com/live/elections-2024#1822561'},
#  {'Headline': 'Only drinking water available amid unprecedented shortage',
#   'Link': 'https://www.dawn.com/news/1900568/only-drinking-water-available-amid-unprecedented-shortage'},
#  {'Headline': '5 killed by armed men blocking highway in Balochistan',
#   'Link': 'https://www.dawn.com/news/1900559'},
#  {'Headline': 'Hamas spokesperson Qanoua killed in Israeli airstrike on Gaza: local media',
#   'Link': 'https://www.dawn.com/live/gaza-invasion'},
# ...

# %%
import csv
with open('dawn_headlines.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=["Headline", "Link"])
    writer.writeheader()
    writer.writerows(data)

print("CSV Saved Successfully as dawn_headlines.csv")
# Out:
# CSV Saved Successfully as dawn_headlines.csv
